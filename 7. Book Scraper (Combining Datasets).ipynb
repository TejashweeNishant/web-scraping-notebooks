# %%
import pandas as pd

# %%
df_1 = pd.read_csv('books.csv')
df_2 = pd.read_csv('data.csv')

# %%
df_1.head()
# Out:
#                                                 link  \
# 0               a-light-in-the-attic_1000/index.html
# 1                  tipping-the-velvet_999/index.html
# 2                          soumission_998/index.html
# 3                       sharp-objects_997/index.html
# 4  sapiens-a-brief-history-of-humankind_996/index...
#
#                                    title  \
# 0                   A Light in the Attic
# 1                     Tipping the Velvet
# 2                             Soumission
# 3                          Sharp Objects
# 4  Sapiens: A Brief History of Humankind
#
#                                             img_link rating  price     stock
# 0  ../media/cache/2c/da/2cdad67c44b002e7ead0cc356...  Three  51.77  In stock
# 1  ../media/cache/26/0c/260c6ae16bce31c8f8c95dadd...    One  53.74  In stock
# 2  ../media/cache/3e/ef/3eef99c9d9adef34639f51066...    One  50.10  In stock
# 3  ../media/cache/32/51/3251cf3a3412f53f339e42cac...   Four  47.82  In stock
# 4  ../media/cache/be/a5/bea5697f2534a2f86a3ef27b5...   Five  54.23  In stock

# %%
df_2.head()
# Out:
#              category  price_e_tax  price_i_tax  tax                 quantity  \
# 0              Poetry        51.77        51.77  0.0  In stock (22 available)
# 1  Historical Fiction        53.74        53.74  0.0  In stock (20 available)
# 2             Fiction        50.10        50.10  0.0  In stock (20 available)
# 3             Mystery        47.82        47.82  0.0  In stock (20 available)
# 4             History        54.23        54.23  0.0  In stock (20 available)
#
#                 upc  reviews
# 0  a897fe39b1053632        0
# 1  90fa61229261140a        0
# 2  6957f44c3847a760        0
# 3  e00eb4fd7b871a48        0
# 4  4165285e1663650f        0

# %%
df=pd.DataFrame()

# %%
df['title']         = df_1['title']
df['upc']           = df_2['upc']
df['category']      = df_2['category']
df['price_e_tax']   = df_2['price_e_tax']
df['price_i_tax']   = df_2['price_i_tax']
df['tax']           = df_2['tax']
df['rating']        = df_1['rating']
df['reviews']       = df_2['reviews']
df['quantity']      = df_2['quantity']
df['stock']         = df_1['stock']
df['link']          = df_1['link']
df['img_link']      = df_1['img_link']

# %%
df
# Out:
#                                                  title               upc  \
# 0                                 A Light in the Attic  a897fe39b1053632
# 1                                   Tipping the Velvet  90fa61229261140a
# 2                                           Soumission  6957f44c3847a760
# 3                                        Sharp Objects  e00eb4fd7b871a48
# 4                Sapiens: A Brief History of Humankind  4165285e1663650f
# ..                                                 ...               ...
# 995  Our Band Could Be Your Life: Scenes from the A...  cd2a2a70dd5d176d
# 996                                               Olio  bfd5e1701c862ac3
# 997  Mesaerion: The Best Science Fiction Stories 18...  19fec36a1dfb4c16
# 998                       Libertarianism for Beginners  f684a82adc49f011
# 999                            It's Only the Himalayas  228ba5e7577e1d49
#
#                category  price_e_tax  price_i_tax  tax rating  reviews  \
# 0                Poetry        51.77        51.77  0.0  Three        0
# 1    Historical Fiction        53.74        53.74  0.0    One        0
# 2               Fiction        50.10        50.10  0.0    One        0
# 3               Mystery        47.82        47.82  0.0   Four        0
# 4               History        54.23        54.23  0.0   Five        0
# ..                  ...          ...          ...  ...    ...      ...
# 995            Classics        55.53        55.53  0.0  Three        0
# 996      Sequential Art        57.06        57.06  0.0    One        0
# 997  Historical Fiction        16.97        16.97  0.0    One        0
# 998             Mystery        53.98        53.98  0.0    Two        0
# 999              Travel        26.08        26.08  0.0    Two        0
#
#                     quantity     stock  \
# 0    In stock (22 available)  In stock
# 1    In stock (20 available)  In stock
# 2    In stock (20 available)  In stock
# 3    In stock (20 available)  In stock
# 4    In stock (20 available)  In stock
# ..                       ...       ...
# 995   In stock (1 available)  In stock
# 996   In stock (1 available)  In stock
# 997   In stock (1 available)  In stock
# 998   In stock (1 available)  In stock
# 999   In stock (1 available)  In stock
#
#                                                   link  \
# 0                 a-light-in-the-attic_1000/index.html
# 1                    tipping-the-velvet_999/index.html
# 2                            soumission_998/index.html
# 3                         sharp-objects_997/index.html
# 4    sapiens-a-brief-history-of-humankind_996/index...
# ..                                                 ...
# 995  our-band-could-be-your-life-scenes-from-the-am...
# 996                                olio_984/index.html
# 997  mesaerion-the-best-science-fiction-stories-180...
# 998        libertarianism-for-beginners_982/index.html
# 999              its-only-the-himalayas_981/index.html
#
#                                               img_link
# 0    ../media/cache/2c/da/2cdad67c44b002e7ead0cc356...
# 1    ../media/cache/26/0c/260c6ae16bce31c8f8c95dadd...
# 2    ../media/cache/3e/ef/3eef99c9d9adef34639f51066...
# 3    ../media/cache/32/51/3251cf3a3412f53f339e42cac...
# 4    ../media/cache/be/a5/bea5697f2534a2f86a3ef27b5...
# ..                                                 ...
# 995  ../media/cache/54/60/54607fe8945897cdcced00441...
# 996  ../media/cache/55/33/553310a7162dfbc2c6d19a84d...
# 997  ../media/cache/09/a3/09a3aef48557576e1a85ba7ef...
# 998  ../media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52...
# 999  ../media/cache/27/a5/27a53d0bb95bdd88288eaf66c...
#
# [1000 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# title          0
# upc            0
# category       0
# price_e_tax    0
# price_i_tax    0
# tax            0
# rating         0
# reviews        0
# quantity       0
# stock          0
# link           0
# img_link       0
# dtype: int64

# %%
df.to_csv('final.csv',index=False)
